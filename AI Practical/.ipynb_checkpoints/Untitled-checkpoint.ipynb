# %%
# !pip install chatterbot
# Out:
# Requirement already satisfied: chatterbot in c:\users\gaikwad\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: mathparse<0.2,>=0.1 in c:\users\gaikwad\anaconda3\lib\site-packages (from chatterbot) (0.1.2)
# Requirement already satisfied: python-dateutil<2.10,>=2.9 in c:\users\gaikwad\anaconda3\lib\site-packages (from chatterbot) (2.9.0.post0)
# Requirement already satisfied: sqlalchemy<2.1,>=2.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from chatterbot) (2.0.30)
# Requirement already satisfied: spacy<3.9,>=3.8 in c:\users\gaikwad\anaconda3\lib\site-packages (from chatterbot) (3.8.4)
# Requirement already satisfied: tqdm in c:\users\gaikwad\anaconda3\lib\site-packages (from chatterbot) (4.66.4)
# Requirement already satisfied: six>=1.5 in c:\users\gaikwad\anaconda3\lib\site-packages (from python-dateutil<2.10,>=2.9->chatterbot) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (0.15.2)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.5.3)
# Requirement already satisfied: jinja2 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from sqlalchemy<2.1,>=2.0->chatterbot) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gaikwad\anaconda3\lib\site-packages (from sqlalchemy<2.1,>=2.0->chatterbot) (3.0.1)
# Requirement already satisfied: colorama in c:\users\gaikwad\anaconda3\lib\site-packages (from tqdm->chatterbot) (0.4.6)
# Requirement already satisfied: language-data>=1.2 in c:\users\gaikwad\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.9,>=3.8->chatterbot) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\gaikwad\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gaikwad\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gaikwad\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gaikwad\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gaikwad\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (2024.7.4)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9,>=3.8->chatterbot) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\gaikwad\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9,>=3.8->chatterbot) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9,>=3.8->chatterbot) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\gaikwad\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9,>=3.8->chatterbot) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from jinja2->spacy<3.9,>=3.8->chatterbot) (2.1.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.9,>=3.8->chatterbot) (1.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gaikwad\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gaikwad\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (0.1.0)

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer

bot = ChatBot('Bot')

trainer = ListTrainer(bot)
trainer.train([
    "Hi, can I help you",
    "Who are you?",
    "I am your virtual assistant. Ask me any questions...",
    "Where do you operate?",
    "We operate from Singapore",
    "What payment methods do you accept?",
    "We accept debit cards and major credit cards",
    "I would like to speak to your customer service agent",
    "please call +65 3333 3333. Our operating hours are from 9am to 5pm, Monday to Friday"
])
trainer.train([
    "What payment methods do you offer?",
    "We accept debit cards and major credit cards",
    "How to contact customer service agent",
    "please call +65 3333 3333. Our operating hours are from 9am to 5pm, Monday to Friday"
])
while True:
    request=input('you :')
    if request == 'OK' or request == 'ok':
        print('Bot: bye')
        break
    else:
        response=bot.get_response(request)
        print('Bot:', response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 from chatterbot import ChatBot
#       2 from chatterbot.trainers import ListTrainer
# ----> 3 bot = ChatBot('Bot')
#       4 trainer = ListTrainer(bot)
#       5 trainer.train([
#       6 "Hi, can I help you",
#       7 "Who are you?",
#    (...)
#      14 "please call +65 3333 3333. Our operating hours are from 9am to 5pm, Monday to Friday"
#      15 ])
#
# File ~\anaconda3\Lib\site-packages\chatterbot\chatterbot.py:61, in ChatBot.__init__(self, name, **kwargs)
#      58 # Logic adapters used by the chat bot
#      59 self.logic_adapters = []
# ---> 61 self.storage = utils.initialize_class(storage_adapter, **kwargs)
#      63 tagger_language = kwargs.get('tagger_language', languages.ENG)
#      65 try:
#
# File ~\anaconda3\Lib\site-packages\chatterbot\utils.py:34, in initialize_class(data, *args, **kwargs)
#      31 else:
#      32     Class = import_module(data)
# ---> 34     return Class(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\chatterbot\storage\sql_storage.py:23, in SQLStorageAdapter.__init__(self, **kwargs)
#      20 def __init__(self, **kwargs):
#      21     super().__init__(**kwargs)
# ---> 23     from sqlalchemy import create_engine, inspect, event
#      24     from sqlalchemy import Index
#      25     from sqlalchemy.engine import Engine
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\__init__.py:13
#      10 from typing import Any
#      12 from . import util as _util
# ---> 13 from .engine import AdaptedConnection as AdaptedConnection
#      14 from .engine import BaseRow as BaseRow
#      15 from .engine import BindTyping as BindTyping
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\__init__.py:18
#       1 # engine/__init__.py
#       2 # Copyright (C) 2005-2024 the SQLAlchemy authors and contributors
#       3 # <see AUTHORS file>
#       4 #
#       5 # This module is part of SQLAlchemy and is released under
#       6 # the MIT License: https://www.opensource.org/licenses/mit-license.php
#       8 """SQL connections, SQL execution and high-level DB-API interface.
#       9
#      10 The engine package defines the basic components used to interface
#    (...)
#      15
#      16 """
# ---> 18 from . import events as events
#      19 from . import util as util
#      20 from .base import Connection as Connection
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\events.py:19
#      16 from typing import Type
#      17 from typing import Union
# ---> 19 from .base import Connection
#      20 from .base import Engine
#      21 from .interfaces import ConnectionEventsTarget
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:30
#      27 from typing import TypeVar
#      28 from typing import Union
# ---> 30 from .interfaces import BindTyping
#      31 from .interfaces import ConnectionEventsTarget
#      32 from .interfaces import DBAPICursor
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\interfaces.py:38
#      36 from ..pool import Pool
#      37 from ..pool import PoolProxiedConnection
# ---> 38 from ..sql.compiler import Compiled as Compiled
#      39 from ..sql.compiler import Compiled  # noqa
#      40 from ..sql.compiler import TypeCompiler as TypeCompiler
#
# ModuleNotFoundError: No module named 'sqlalchemy.sql'
